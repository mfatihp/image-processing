# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv.imread("leaf.jpg")

# %%
plt.figure(figsize=(11,6))
plt.imshow(image)
plt.show()

# %%
image.shape
# Out:
# (549, 732, 3)

# %%
type(image)
# Out:
# numpy.ndarray
